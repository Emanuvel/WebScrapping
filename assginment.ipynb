# %% [markdown]
# ## install libraries

# %%
pip install requests

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## importing labrires

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as ko

# %% [markdown]
# ## scrapping website

# %%
url="https://www.flipkart.com/search?q=panda+teddy&as=on&as-show=on&otracker=AS_Query_PredictiveAutoSuggest_10_0_na_na_na&otracker1=AS_Query_PredictiveAutoSuggest_10_0_na_na_na&as-pos=10&as-type=PREDICTIVE&suggestionId=panda+teddy&requestId=a3a07c14-d505-40f8-916d-f2b7af540713"

# %% [markdown]
# ## website response

# %%
res=requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %% [markdown]
# ## parsing

# %%
soup=BeautifulSoup(res.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## toys

# %%
pandas=soup.select("")

# %%
phone_name
# Out:
# [<div class="_4rR01T">REDMI 10 (Pacific Blue, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Midnight Black, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Caribbean Green, 64 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Pacific Blue, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Midnight Black, 128 GB)</div>,
#  <div class="_4rR01T">REDMI 10 (Caribbean Green, 128 GB)</div>,
#  <div class="_4rR01T">HTC 10 (carbon gray, 32 GB)</div>,
#  <div class="_4rR01T">Mi 10 (Twilight Grey, 128 GB)</div>,
#  <div class="_4rR01T">HTC 10 (Topaz Gold, 32 GB)</div>,
#  <div class="_4rR01T">Mi 10 (Coral Green, 256 GB)</div>,
#  <div class="_4rR01T">Honor 10 (Midnight Black, 128 GB)</div>,
#  <div class="_4rR01T">Honor 10 (Phantom Blue, 128 GB)</div>,
#  <div class="_4rR01T">Mi 10 (Twilight Grey, 256 GB)</div>,
#  <div class="_4rR01T">Mi 10 (Coral Green, 128 GB)</div>,
#  <div class="_4rR01T">REDMI Note 10S (Deep Sea Blue, 64 GB)</div>,
# ...

# %%
spec=soup.select('.rgWa7D:nth-child(1)')

# %%
spec
# Out:
# []

# %%
Battery=soup.select('.rgWa7D:nth-child(4)')

# %%
Battery
# Out:
# [<li class="rgWa7D">5000 mAh Lithium-Ploymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">2500 mAh Battery</li>,
#  <li class="rgWa7D">6000 mAh Lithium-ion Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">6000 mAh Lithium-ion Battery</li>,
#  <li class="rgWa7D">6000 mAh Li-ion Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium-Ploymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium-ion Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium-Ploymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Lithium Polymer Battery</li>,
#  <li class="rgWa7D">5000 mAh Li-Polymer Battery</li>,
# ...

# %%
df=ko.DataFrame(mobile,columns=["mobile"])

# %%
df
# Out:
#                                          mobile
# 0         REDMI Note 10S (Deep Sea Blue, 64 GB)
# 1             realme 9 5G (Meteor Black, 64 GB)
# 2          realme 9 5G (Stargaze White, 128 GB)
# 3                                  Good One AIR
# 4   SAMSUNG Galaxy F12 (Celestial Black, 64 GB)
# 5           realme 9 5G (Stargaze White, 64 GB)
# 6         SAMSUNG Galaxy F12 (Sea Green, 64 GB)
# 7   Infinix HOT 12 Play (Daylight Green, 64 GB)
# 8         REDMI Note 10S (Cosmic Purple, 64 GB)
# 9                  POCO C31 (Royal Blue, 64 GB)
# 10     REDMI Note 10T 5G (Metallic Blue, 64 GB)
# 11           realme 9 5G (Meteor Black, 128 GB)
# 12            realme C35 (Glowing Green, 64 GB)
# 13          REDMI Note 10S (Frost White, 64 GB)
# 14            realme C35 (Glowing Black, 64 GB)
# 15          REDMI 9i Sport (Coral Green, 64 GB)
# 16        REDMI 9i Sport (Metallic Blue, 64 GB)
# 17               REDMI 10 (Pacific Blue, 64 GB)
# 18         SAMSUNG Galaxy F12 (Sky Blue, 64 GB)
# ...

# %%
df['spec']=spec

# %%
df
# Out:
#                                          mobile  \
# 0         REDMI Note 10S (Deep Sea Blue, 64 GB)
# 1             realme 9 5G (Meteor Black, 64 GB)
# 2          realme 9 5G (Stargaze White, 128 GB)
# 3                                  Good One AIR
# 4   SAMSUNG Galaxy F12 (Celestial Black, 64 GB)
# 5           realme 9 5G (Stargaze White, 64 GB)
# 6         SAMSUNG Galaxy F12 (Sea Green, 64 GB)
# 7   Infinix HOT 12 Play (Daylight Green, 64 GB)
# 8         REDMI Note 10S (Cosmic Purple, 64 GB)
# 9                  POCO C31 (Royal Blue, 64 GB)
# 10     REDMI Note 10T 5G (Metallic Blue, 64 GB)
# 11           realme 9 5G (Meteor Black, 128 GB)
# 12            realme C35 (Glowing Green, 64 GB)
# 13          REDMI Note 10S (Frost White, 64 GB)
# 14            realme C35 (Glowing Black, 64 GB)
# 15          REDMI 9i Sport (Coral Green, 64 GB)
# 16        REDMI 9i Sport (Metallic Blue, 64 GB)
# 17               REDMI 10 (Pacific Blue, 64 GB)
# ...

# %%
df['Battery']=Battery

# %%
df
# Out:
#                                          mobile  \
# 0         REDMI Note 10S (Deep Sea Blue, 64 GB)
# 1             realme 9 5G (Meteor Black, 64 GB)
# 2          realme 9 5G (Stargaze White, 128 GB)
# 3                                  Good One AIR
# 4   SAMSUNG Galaxy F12 (Celestial Black, 64 GB)
# 5           realme 9 5G (Stargaze White, 64 GB)
# 6         SAMSUNG Galaxy F12 (Sea Green, 64 GB)
# 7   Infinix HOT 12 Play (Daylight Green, 64 GB)
# 8         REDMI Note 10S (Cosmic Purple, 64 GB)
# 9                  POCO C31 (Royal Blue, 64 GB)
# 10     REDMI Note 10T 5G (Metallic Blue, 64 GB)
# 11           realme 9 5G (Meteor Black, 128 GB)
# 12            realme C35 (Glowing Green, 64 GB)
# 13          REDMI Note 10S (Frost White, 64 GB)
# 14            realme C35 (Glowing Black, 64 GB)
# 15          REDMI 9i Sport (Coral Green, 64 GB)
# 16        REDMI 9i Sport (Metallic Blue, 64 GB)
# 17               REDMI 10 (Pacific Blue, 64 GB)
# ...

# %%
df.to_csv('mdetails.csv')

# %%
kf=ko.read_csv('C:/Users/admin/Documents/PMIST B2-Data analytics/mdetails.csv')

# %%
kf
# Out:
#     Unnamed: 0                                       mobile  \
# 0            0        REDMI Note 10S (Deep Sea Blue, 64 GB)
# 1            1            realme 9 5G (Meteor Black, 64 GB)
# 2            2         realme 9 5G (Stargaze White, 128 GB)
# 3            3                                 Good One AIR
# 4            4  SAMSUNG Galaxy F12 (Celestial Black, 64 GB)
# 5            5          realme 9 5G (Stargaze White, 64 GB)
# 6            6        SAMSUNG Galaxy F12 (Sea Green, 64 GB)
# 7            7  Infinix HOT 12 Play (Daylight Green, 64 GB)
# 8            8        REDMI Note 10S (Cosmic Purple, 64 GB)
# 9            9                 POCO C31 (Royal Blue, 64 GB)
# 10          10     REDMI Note 10T 5G (Metallic Blue, 64 GB)
# 11          11           realme 9 5G (Meteor Black, 128 GB)
# 12          12            realme C35 (Glowing Green, 64 GB)
# 13          13          REDMI Note 10S (Frost White, 64 GB)
# 14          14            realme C35 (Glowing Black, 64 GB)
# ...

# %%
kf['spec']=kf['spec'].str.strip('<li class="rgWa7D"></li>').astype(str)

# %%
kf['Battery']=kf['Battery'].str.strip('<li class="rgWa7D"></li>').astype(str)

# %%
kf
# Out:
#     Unnamed: 0                                       mobile  \
# 0            0        REDMI Note 10S (Deep Sea Blue, 64 GB)
# 1            1            realme 9 5G (Meteor Black, 64 GB)
# 2            2         realme 9 5G (Stargaze White, 128 GB)
# 3            3                                 Good One AIR
# 4            4  SAMSUNG Galaxy F12 (Celestial Black, 64 GB)
# 5            5          realme 9 5G (Stargaze White, 64 GB)
# 6            6        SAMSUNG Galaxy F12 (Sea Green, 64 GB)
# 7            7  Infinix HOT 12 Play (Daylight Green, 64 GB)
# 8            8        REDMI Note 10S (Cosmic Purple, 64 GB)
# 9            9                 POCO C31 (Royal Blue, 64 GB)
# 10          10     REDMI Note 10T 5G (Metallic Blue, 64 GB)
# 11          11           realme 9 5G (Meteor Black, 128 GB)
# 12          12            realme C35 (Glowing Green, 64 GB)
# 13          13          REDMI Note 10S (Frost White, 64 GB)
# 14          14            realme C35 (Glowing Black, 64 GB)
# ...
